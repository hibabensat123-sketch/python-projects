# %%
book_cost = 7.99
notebook_cost =4.59
discount = 0.15 
total_cost=(book_cost+notebook_cost)-discount
print(total_cost)
# Out:
# 12.43

# %%
input()
# Out:
#  123
# '123'

# %%
a=input('please enter a number:') 
print('you entered:',a)
# Out:
# please enter a number: 1
# you entered: 1

# %%
# Out:
# please enter a number: 1
# you entered: 1

# %%
x=input('please enter a number:') 
print('you entered:',x)
# Out:
# please enter a number: a
# you entered: a

# %%
x=int(input('please enter a number:'))
x+= 1
print('You entered:' , x)
# Out:
# please enter a number: 1
# You entered: 2

# %%
x=int(input('please enter a number:'))
x+= 1
print('You entered:' , x)
# Out:
# please enter a number: 1
# You entered: 2

# %%
x=input()
print(x)
# Out:
#  1
# 1

# %%
n=float(input())
n=n/2
print(n)
# Out:
#  1
# 0.5

# %%
w=int(input())
w=w+9
print(w)
# Out:
#  9
# 18

# %%
b=int(input())
print(not b)
# Out:
#  1
# False

# %%
x=5 
if(x>3):
    x-=3
print(x)
# Out:
# 2

# %%
code=input()
if(code=="123"):
    print("unlocked")
# Out:
#  1

# %%
name=input("name: ")
if(name!= ""):
    print ("Your name is :", name)
# Out:
# name:  Hiba
# Your name is : Hiba

# %%
x=int(input("enter a whole number: "))
y=6
if (x<y):
    print("your number is smaller than", y)
else:
    print("your number is", y, "or greater")
# Out:
# enter a whole number:  24
# your number is 6 or greater

# %%
x=int(input("enter a whole number: "))
y=6
if (x<y):
    print("your number is smaller than", y)
else:
    print("your number is", y, "or greater")
# Out:
# enter a whole number:  4
# your number is smaller than 6

# %%
int(input("entera whole number: "))
y=6 
z=15
if (x<y):
    print("your number is smaller than", y)
elif (x>z):
    print("your number is greater than", z)
else:
    print("your number is between", y, "and", z)
# Out:
# entera whole number:  10
# your number is smaller than 6

# %%
x=int(input("entera whole number: "))
y=6 
z=15
if (x<y):
    print("your number is smaller than", y)
elif (x>z):
    print("your number is greater than", z)
else:
    print("your number is between", y, "and", z)
# Out:
# entera whole number:  10
# your number is between 6 and 15

# %%
#ask the user to enter the current temperature 
temperature= int(input("what is the current temperature? "))
#compare temerature and choose outfit
if temperature >= 80:
    outfit="shorts and pack your sunglasses"
elif 60<= temperature <=79:
    outfit="a light jacket"
else:
    outfit="a coat in addition to a hat, gloves, and a scarf"   
#advice for the user
    
    advice = f"Today you should wear {outfit}."
print(advice)
# Out:
# what is the current temperature?  90
# Today you should wear shorts and pack your sunglasses.

# %%
# Ask the user to enter the current temperature
temperature = int(input("What is the current temperature? "))

# Compare temperature and choose outfit
if temperature >= 80:
    outfit = "shorts and pack your sunglasses"
elif 60 <= temperature <= 79:
    outfit = "a light jacket"
else:
    outfit = "a coat in addition to a hat, gloves, and scarf"

# Advice for the user
advice = f"Today you should wear {outfit}."

print(advice)
# Out:
# What is the current temperature?  90
# Today you should wear shorts and pack your sunglasses.

# %%
x=int(input("enter a whole number: "))
y=6
print(f"your number is smaller than {y}" if x < y else f"your number is{y} or greater")
# Out:
# enter a whole number:  8
# your number is6 or greater

# %%
x= int(input())
print(f"is in the range {x}" if x>0 and x<5 else f"is not in the range {x}")
# Out:
#  4
# is in the range 4

# %%
x=int(input())
print(f"is not in the range {x}" if x <=0 or x>= 5 else(f" is in the range {x}"))
# Out:
#  7
# is not in the range 7

# %%
x= int(input())
if(x>0):
    print(x, "is positive ")
# Out:
#  1
# 1 is positive

# %%
x=int(input("enter a number:"))
print(f"is big {x}" if x>=0 else f"is small {x}")
# Out:
# enter a number: 10
# is big 10

# %%
x=int(input("enter a number:"))
print(f" is high {x}" if x>5 else f"is low {x}")
# Out:
# enter a number: 2
# is low 2

# %%
x=int(input("enter a number:"))
print(f"{x} is even" if x % 2 == 0 else f"{x} is odd")
# Out:
# 1 is odd

# %%
x=number 
condition:
if x % 2 == 0 is even 
elif x % 3 == 0 is multiple of 3 
else is other 
x= int(input("enter a number: "))
if x % 2 == 0: 
 print(f"{x} is even")
elif x % 3 == 0:
 print(f"{x} is multiple of 3")
else:
 print(f"{x} is other")

# %%
x= number 
condition:
if x % 2 == 0 and x > 10 is Big Even 
elif x % 2 == 0 is Small Even 
elif x > 10 is Big Odd 
else is Small Odd 
x= int(input( "enter a number:"))
if x % 2 == 0 and x > 10:
    print(f"{x} is Big Even")
elif x % 2 == 0:
    print(f"{x} is Small Even")
elif x > 10:
    print(f"{x} is Big Odd")
else:
    print(f"{x} is Small Odd")

# %%
x= age 
y= number of visits per week 

condition:
if x <= 18 and y <= 3 is Active Teen 
elif x <18 is Teen 
elif x >= 18 and y >= 4 is Active adults 
else is Regular 

x= int(input("Enter your Age: "))
y= int(input("Enter number of tickets: "))

if x <= 18 and y <= 3:
 print("Active Teen")
elif x < 18:
 print("Teen")
elif x >= 18 and y >= 4:
 print("Active adults")
else:
 print("Regular")

# %%
x = age 
y = amout spent 
condition:
if x<18 and y>=30 is Young VIP   
elif x<18 is Young 
elif x>=18 and y>=50 is VIP
else is Standard 
x=int(input("Enter your age: "))
y=int(input("Enter the amout you're spending: "))
if x<18 and y>=30:
    print("Young VIP")
elif x<18:
    print("Young")
elif x>=18 and y>=50:
    print("VIP")
else:
    print("Standard")

# %%
x= order value 
y=distance 
condition:
if x>=100 and y<=5 is High priority 
elif x>=100 is Value Priority
elif y<=5 is Distance Priority 
else is Standard 

x=int(input("Enter the order value:"))
y= int(input("Enter The order\'s distance: "))
if x>=100 and y<=5:
    print("High priority")
elif x>=100: 
    print("Value Priority")
elif y<=5: 
    print("Distance Priority")
else:
    print("Standard")

# %%
x= number
choice = 

if check and x>0 is prositive 
elif check and x==0 is zero 
elif check and x<0 
else is invalid 

x= int(input("enter your number:"))
choice=input("enter Type of choice:")
        
if type_of_choice

# %%
x= int(input("Enter a number: "))
code= input("Enter type of code: ")

if code == "open" and x>10:
    print("Access Granted")
elif code == "open" and x<=10:
    print("Low Access")
else:
    print("Denied")

# %%
x= score 
status= type of status 
x= int(input("Enter your score: "))
status= input("Enter type of status:")

if status == "active" and x>=80:
    print("Top active")
elif status == "active":
    print("active")
elif x>= 80:
    print("Top Inactive")
else:
    print("Inactive")

# %%
x=int(input("Enter a number: "))
mode = input("Enter a mode:")

if mode == "go":
    if x>10:
        if x==15:
            print("Special Approved")
        else:
            print("Approved")
    else:
         print("Rejected")
else:
   print("invalid")

# %%
x= number 
mode = type of mode 
x= int(input("Enter a number:"))
mode= input("Enter type of mode: ")

if mode == "pay":
    if x>50:
        if x==75:
            print("Priority Approved")
        else:
            print("Approved")
    else:
        print("Review")
else:
    print("Blocked")

# %%
x= number 
mode= type of mode 
flag= type of flag 

x= int(input("Enter a number:"))
mode= input("Enter type of mode:")
 if mode == "pay" and x>50 and flag == "yes":
     print("Priority Approved")
 elif mode == "pay" and x>50:
     print("Approved")
     if x==75:
         print("Special Case")
     else:
         print("Review")
else:
    print("Blocked")

# %%
x= number 
mode= type of mode 
flag= type of flag 

x= int(input("Enter a number:"))
mode= input("Enter type of mode:")
flag= input("Enter type of flag: ")
if x==40:
    print("Special Access")
elif mode == "enter" and x>30 and flag == "yes":
    print("Priority Access")
elif mode == ("enter") and x>30:
    print("Access")
elif mode == "enter" and x<=30:
    print("Wait")
else:
    print("Denied")

# %%
x= amount  
mode = type of mode 
verification = verification status 
x= int(input("Enter the amount:"))
mode= input("Enter type of mode:")
verification= input("Enter status of verification:")

if x == 0:
    print("Blocked")
elif x>1000:
    print("Manual Review")
elif mode == "fast" and verification == "yes" and x>100:
    print("Fast Transfer")
elif mode == "fast" and x>100:
     print("Standard Transfer")
elif mode == "fast" and x<=100:
    print("Pending Verification")
else:
    print("Rejected")

# %%
x= number of attempts 
role= type of role 
status= type of status 
x= int(input("Enter the number of attempts: "))
role= input("Enter type of Role: ")
status= input("Enter type of status: ")
if x>=3:
    print("Locked")
elif role == "admin" and status == "active" and x==2:
    print("Admin Warning")
elif role == "admin" and status == "active":
    print("Admin Access")
elif role == "user" and status == "active":
    print("User Access")
elif role == "guest": 
    print("Guest Access")
else: 
    print("Denied")

# %%
x= price number 
type= order_type
membership= type of membership 
x= int(input("Enter the price number: "))
order_type= input("Enter the type:")
membership= input("Enter the type of membership:")
if x==0:
    print("Cancelled")
elif x>500:
    print("High Value Review")
elif order_type == "premium" and membership == "gold" and x == 150:
    print("Special Premium")
elif order_type == "premium" and membership == "gold" and x>100:
    print("Premium Order")
elif order_type == "premium" and x>100:
    print("Standard Order")
elif order_type == "basic":
    print("Basic Order")
else:
    print("Rejected")

# %%
n= int(input("enter n: "))
total=0 
count=1
while count <=n:
    total+=count
    count+=1 
    print("the total is", total)
# Out:
# enter n:  2
# the total is 1
# the total is 3

# %%
x = input("Enter x: ")
